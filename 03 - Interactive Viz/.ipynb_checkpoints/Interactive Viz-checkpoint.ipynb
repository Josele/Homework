# %% [markdown]
# # Import Data
#
# To import the data, first we open it as a raw file. And it's separate by ';'. So let's parse it.

# %%
#imports required
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import requests
import csv
import os.path
#import googlemaps
from datetime import datetime

#check csv is already created, in order to avoid using maps API due to exceeded limits
exists_previously=False

def retrievePostalCode(input):
    input+=', Switzerland'
    response=requests.get('https://maps.googleapis.com/maps/api/place/textsearch/json?query='+input+'&key=AIzaSyAFguCnscOv7flXNyvYM5YMYzPx9RJnne8')
    if(response.json()['status']!='ZERO_RESULTS'):
        #if(response.json()['results']==[]):#APIKEY EXCEEDED
        return response.json()['results'][0]['geometry']['location']
    return ' '

def retrieveCanton(a,b):
#geonames encoding
#    input=input.replace(' ','&x20')
#    print('retrieving canton from input:',input)Berner&x20Fachhochschule&x20-&x20BFH&x20suisse
#geonames
    response=requests.get('http://api.geonames.org/findNearbyJSON?lat='+str(a)+'&lng='+str(b)+'&username=alvarogg777')
#    response=requests.get('http://api.geonames.org/searchJSON?q='+input+'&country=CH&maxRows=10&username=alvarogg777')
    #print(response.json())
    if(len(response.json()['geonames'])>0):
        return response.json()['geonames'][0]['adminCode1']
    return ' '


if(os.path.isfile('grants.csv')): 
    df_group_aux=pd.read_csv('grants.csv', sep=",")
    exists_previously=True
    df_group_aux
else:
    df = pd.read_csv("P3_GrantExport.csv", sep=";")

    df.columns
    df_aux=df[['University', 'Approved Amount']]
    df_aux=df_aux.dropna()
    df_aux['Approved Amount'] = df_aux['Approved Amount'].apply(pd.to_numeric,errors='coerce')

    df_group=df_aux.groupby('University').sum()
    df_count=df_aux.groupby('University').count()
    df_group['Grants approved']=df_count['Approved Amount']

    #Unemployment with custom defined scale
    county_geo = r'ch-cantons.topojson.json'
    #map_2 = folium.Map(location=[40, -99], zoom_start=4)
    #map_2.choropleth(geo_path=county_geo, data_out='data2.json', data=df,
    #               columns=['GEO_ID', 'Unemployment_rate_2011'],
    #               key_on='feature.id',
    #               threshold_scale=[0, 5, 7, 9, 11, 13],
    #               fill_color='YlGnBu', line_opacity=0.3,
    #               legend_name='Unemployment Rate 2011 (%)',
    #               topojson='objects.us_counties_20m')
    #map_2.save('map_2.html')
    #map_2
    #coverage=len(df_aux)/len(df)
    df_aux2=df[['University', 'Approved Amount']]
    df_aux_num=df_aux
    df_aux_num=df_aux_num['Approved Amount'].astype(str)
    print(len(df_aux_num),len(df_aux2),len(df_aux2[df_aux2.isin(df_aux_num)]))
    #como puedes ver hay valores Approved amount no numericos o bien hay University no numericos.
    df_not_num=df[~df.index.isin(df_aux_num.index)]
    #gmaps = googlemaps.Client(key='AIzaSyBlgWuQQ05dJxrgQOo-InqGbH2y_Tlu0jg')


    # Geocoding an address
    #retrievePostalCode('EPFL, Suisse')
    #df_group.index
    cantonList=[]
    df_group['CANTON']=' '
    for i in df_group.index:
        #    print(i)
        postalcode=retrievePostalCode(i)
        if(postalcode==' '):
            continue
        #print(postalcode)
        latlng=postalcode#latlng['lat'], latlng['lng']
    #    print('return postal code:',ret)
    #geoname
        canton=retrieveCanton(latlng['lat'],latlng['lng'])
        if(canton!=' '):
    #        print(i,index,df_group[i])
            df_group.set_value(i,'CANTON',canton)
            cantonList.append(canton)
    print('found cantonList:',cantonList)
    df_group
# Out:
# Universität Luzern - LU                                3.998168e+07
# Universität St. Gallen - SG                            6.919495e+07
# Universität Zürich - ZH                                1.826843e+09
# Université de Fribourg - FR                            4.575262e+08
# Université de Genève - GE                              1.838237e+09
# Université de Lausanne - LA                            1.183291e+09
# Université de Neuchâtel - NE                           3.832046e+08
#
#                                                     Grants approved CANTON
# University
# Allergie- und Asthmaforschung - SIAF                             44     GR
# Berner Fachhochschule - BFH                                     136     BE
# Biotechnologie Institut Thurgau - BITG                            8     TG
# Centre de rech. sur l'environnement alpin - CREALP                8     VS
# EPF Lausanne - EPFL                                            4406     VD
# ETH Zürich - ETHZ                                              6143     ZH
# Eidg. Anstalt für Wasserversorgung - EAWAG                      333     ZH
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL              223     ZH
# Eidg. Hochschulinstitut für Berufsbildung - EHB                  12     BE
# Eidg. Material und Prüfungsanstalt - EMPA                       238     SG
# Ente Ospedaliero Cantonale - EOC                                 21     TI
# Fachhochschule Kalaidos - FHKD                                    3     ZH
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW                 225     SO
# Fachhochschule Ostschweiz - FHO                                  26     SG
# Facoltà di Teologia di Lugano - FTL                               2     TI
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS                1     VS
# Forschungsinstitut für Opthalmologie - IRO                       14     VS
# Forschungsinstitut für biologischen Landbau - FIBL               17     AG
# Franklin University Switzerland - FUS                             6     TI
# Friedrich Miescher Institute - FMI                               84     BS
# HES de Suisse occidentale - HES-SO                              271     JU
# Haute école pédagogique BE, JU, NE - HEPBEJUNE                    7     JU
# Haute école pédagogique du canton de Vaud - HEPL                 16     VD
# Haute école pédagogique fribourgeoise - HEPFR                     7     FR
# Hochschule Luzern - HSLU                                         62     LU
# Idiap Research Institute - IDIAP                                 82     VS
# Inst. Suisse de Spéléologie et Karstologie - ISSKA                3     NE
# Inst. de Hautes Etudes Internat. et du Dév - IHEID              198     GE
# Inst. universit. romand de Santé au Travail - IST                35     VD
# Institut Universitaire Kurt Bösch - IUKB                         21     VS
# ...                                                             ...    ...
# Instituto Ricerche Solari Locarno - IRSOL                         5     TI
# Interkant. Hochschule für Heilpädagogik ZH - HfH                 22     ZH
# Istituto Svizzero di Roma - ISR                                   6     07
# Kantonsspital St. Gallen - KSPSG                                 48     SG
# Paul Scherrer Institut - PSI                                    537     AG
# Pädagogische Hochschule Bern - PHBern                            13     BE
# Pädagogische Hochschule Graubünden - PHGR                         7     GR
# Pädagogische Hochschule Luzern - PHLU                            14     LU
# Pädagogische Hochschule Nordwestschweiz - PHFHNW                 20     SO
# Pädagogische Hochschule Schaffhausen - PHSH                       1     SH
# Pädagogische Hochschule Schwyz - PHSZ                             5     SZ
# Pädagogische Hochschule St. Gallen - PHSG                        13     SG
# Pädagogische Hochschule Thurgau - PHTG                            6     TG
# Pädagogische Hochschule Zug - PHZG                                7     ZG
# Pädagogische Hochschule Zürich - PHZFH                           23     ZH
# SUP della Svizzera italiana - SUPSI                             135     TI
# Schweiz. Hochschule für Logopädie Rorschach - SHLR                2     SG
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA               20     ZH
# Schweizer Paraplegiker Forschung - SPF                           10     LU
# Swiss Center for Electronics and Microtech. - CSEM               28     NE
# Università della Svizzera italiana - USI                        346     TI
# Universität Basel - BS                                         4737     BS
# Universität Bern - BE                                          5460     BE
# Universität Luzern - LU                                         214     LU
# Universität St. Gallen - SG                                     426     SG
# Universität Zürich - ZH                                        6754     ZH
# Université de Fribourg - FR                                    2078     FR
# Université de Genève - GE                                      6379     GE
# Université de Lausanne - LA                                    4090     VD
# Université de Neuchâtel - NE                                   1589     NE
#
# [61 rows x 3 columns]

# %%
#we remove non found universities
if(exists_previously==False):
    df_group=df_group[df_group.CANTON!=' ']
    df_group

# %%
if(exists_previously==False):
    #let's reindex it, in order to plot it right
    df_group_aux=df_group[['CANTON','Approved Amount','Grants approved']]
    df_group_aux.reset_index(inplace=True)
df_group_aux
# Out:
#                                            University CANTON  Approved Amount  \
# 0                Allergie- und Asthmaforschung - SIAF     GR     1.916996e+07
# 1                         Berner Fachhochschule - BFH     BE     3.102870e+07
# 2              Biotechnologie Institut Thurgau - BITG     TG     2.492535e+06
# 3   Centre de rech. sur l'environnement alpin - CR...     VS     1.567678e+06
# 4                                 EPF Lausanne - EPFL     VD     1.175316e+09
# 5                                   ETH Zürich - ETHZ     ZH     1.635597e+09
# 6          Eidg. Anstalt für Wasserversorgung - EAWAG     ZH     7.461922e+07
# 7   Eidg. Forschungsanstalt für Wald,Schnee,Land -...     ZH     4.836039e+07
# 8     Eidg. Hochschulinstitut für Berufsbildung - EHB     BE     2.086572e+06
# 9           Eidg. Material und Prüfungsanstalt - EMPA     SG     5.857452e+07
# 10                   Ente Ospedaliero Cantonale - EOC     TI     5.067172e+06
# 11                     Fachhochschule Kalaidos - FHKD     ZH     1.090280e+06
# 12    Fachhochschule Nordwestschweiz (ohne PH) - FHNW     SO     4.277191e+07
# 13                    Fachhochschule Ostschweiz - FHO     SG     4.437056e+06
# 14                Facoltà di Teologia di Lugano - FTL     TI     8.000000e+03
# 15  Fernfachhochschule Schweiz (Mitglied SUPSI) - ...     VS     1.200000e+04
# 16         Forschungsinstitut für Opthalmologie - IRO     VS     3.478469e+06
# 17  Forschungsinstitut für biologischen Landbau - ...     AG     7.442410e+06
# 18              Franklin University Switzerland - FUS     TI     6.595600e+04
# 19                 Friedrich Miescher Institute - FMI     BS     4.022914e+07
# 20                 HES de Suisse occidentale - HES-SO     JU     3.416297e+07
# 21     Haute école pédagogique BE, JU, NE - HEPBEJUNE     JU     6.273800e+05
# 22   Haute école pédagogique du canton de Vaud - HEPL     VD     1.430686e+06
# 23      Haute école pédagogique fribourgeoise - HEPFR     FR     1.547498e+06
# 24                           Hochschule Luzern - HSLU     LU     1.076812e+07
# 25                   Idiap Research Institute - IDIAP     VS     2.218311e+07
# 26  Inst. Suisse de Spéléologie et Karstologie - I...     NE     6.248190e+05
# 27  Inst. de Hautes Etudes Internat. et du Dév - I...     GE     3.886423e+07
# 28  Inst. universit. romand de Santé au Travail - IST     VD     6.882730e+06
# 29           Institut Universitaire Kurt Bösch - IUKB     VS     1.977340e+06
# ..                                                ...    ...              ...
# 31          Instituto Ricerche Solari Locarno - IRSOL     TI     9.512380e+05
# 32   Interkant. Hochschule für Heilpädagogik ZH - HfH     ZH     2.839872e+06
# 33                    Istituto Svizzero di Roma - ISR     07     1.410000e+05
# 34                   Kantonsspital St. Gallen - KSPSG     SG     1.503410e+07
# 35                       Paul Scherrer Institut - PSI     AG     1.152690e+08
# 36              Pädagogische Hochschule Bern - PHBern     BE     1.990390e+06
# 37          Pädagogische Hochschule Graubünden - PHGR     GR     6.146130e+05
# 38              Pädagogische Hochschule Luzern - PHLU     LU     1.979281e+06
# 39   Pädagogische Hochschule Nordwestschweiz - PHFHNW     SO     3.476142e+06
# 40        Pädagogische Hochschule Schaffhausen - PHSH     SH     1.766910e+05
# 41              Pädagogische Hochschule Schwyz - PHSZ     SZ     9.365510e+05
# 42          Pädagogische Hochschule St. Gallen - PHSG     SG     2.098387e+06
# 43             Pädagogische Hochschule Thurgau - PHTG     TG     1.526446e+06
# 44                 Pädagogische Hochschule Zug - PHZG     ZG     4.957150e+05
# 45             Pädagogische Hochschule Zürich - PHZFH     ZH     3.298346e+06
# 46                SUP della Svizzera italiana - SUPSI     TI     2.404008e+07
# 47  Schweiz. Hochschule für Logopädie Rorschach - ...     SG     4.296000e+05
# 48  Schweiz. Institut für Kunstwissenschaft - SIK-...     ZH     4.649550e+06
# 49             Schweizer Paraplegiker Forschung - SPF     LU     1.944211e+06
# 50  Swiss Center for Electronics and Microtech. - ...     NE     1.806825e+07
# 51           Università della Svizzera italiana - USI     TI     8.497055e+07
# 52                             Universität Basel - BS     BS     1.352251e+09
# 53                              Universität Bern - BE     BE     1.519373e+09
# 54                            Universität Luzern - LU     LU     3.998168e+07
# 55                        Universität St. Gallen - SG     SG     6.919495e+07
# 56                            Universität Zürich - ZH     ZH     1.826843e+09
# 57                        Université de Fribourg - FR     FR     4.575262e+08
# 58                          Université de Genève - GE     GE     1.838237e+09
# 59                        Université de Lausanne - LA     VD     1.183291e+09
# 60                       Université de Neuchâtel - NE     NE     3.832046e+08
#
#     Grants approved
# 0                44
# 1               136
# 2                 8
# 3                 8
# 4              4406
# 5              6143
# 6               333
# 7               223
# 8                12
# 9               238
# 10               21
# 11                3
# 12              225
# 13               26
# 14                2
# 15                1
# 16               14
# 17               17
# 18                6
# 19               84
# 20              271
# 21                7
# 22               16
# 23                7
# 24               62
# 25               82
# 26                3
# 27              198
# 28               35
# 29               21
# ..              ...
# 31                5
# 32               22
# 33                6
# 34               48
# 35              537
# 36               13
# 37                7
# 38               14
# 39               20
# 40                1
# 41                5
# 42               13
# 43                6
# 44                7
# 45               23
# 46              135
# 47                2
# 48               20
# 49               10
# 50               28
# 51              346
# 52             4737
# 53             5460
# 54              214
# 55              426
# 56             6754
# 57             2078
# 58             6379
# 59             4090
# 60             1589
#
# [61 rows x 4 columns]

# %%
if(exists_previously==False):
    #let's save the df as csv file
    df_group_aux.to_csv('grants.csv')
#amount grants with custom defined scale 46.7912768,5.9814057,7
map_2 = folium.Map(location=[46.8, 8.5], zoom_start=8)
map_2.choropleth(geo_path=county_geo, data=df_group_aux,
               columns=['CANTON', 'Approved Amount'],
               #key_on='feature.canton',
               threshold_scale=[0, 5, 7, 9, 11, 13],
               fill_color='YlOrRd', line_opacity=0.3,
               legend_name='Universities Approved Amount (%)',
                topojson = 'objects.cantons')
map_2.save('map_2.html')
map_2
# Out:
#   File "<ipython-input-36-39e6c82c0000>", line 8
#     key_on='feature.'CANTON'',
#                           ^
# SyntaxError: invalid syntax
